# %% [markdown]
# ## TESTNOTEBOOK
#
# **SUPER** *awesome* `notebook`

# %%
print('This is a test notebook')
# Out:
# This is a test notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.randint(0,10,10)
y = np.random.randint(0,10,10)

plt.plot(x,y)
plt.show()
